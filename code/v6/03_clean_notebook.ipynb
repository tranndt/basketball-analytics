# %%
import pandas as pd
import numpy as np
import sys
import os
import bs4
from IPython.display import display_html,clear_output, HTML
import re
from datetime import datetime
import ast
import itertools
from tqdm import tqdm,trange
from file_tools import *
from request_tools import *
import parse_tools as pt
import pyarrow as pa

# %%
# Import and clean data from data-parsed folder
SRC_DIR = './data-parsed/teams/BOS/2022'
TGL_TYPE_CSV = 'tgl_basic.csv'
df = pd.read_csv(f'{SRC_DIR}/{TGL_TYPE_CSV}',header=[0,1]).drop(columns=[('Unnamed: 0_level_0','Unnamed: 0_level_1')])
df
# Out:
#    Match
#        G        Date   Tm          Tm_href H/A  Opp              Opp_href
# 0      1  2021-10-20  BOS  /teams/BOS/2022   0  NYK  /teams/NYK/2022.html  \
# 1      2  2021-10-22  BOS  /teams/BOS/2022   1  TOR  /teams/TOR/2022.html
# 2      3  2021-10-24  BOS  /teams/BOS/2022   0  HOU  /teams/HOU/2022.html
# 3      4  2021-10-25  BOS  /teams/BOS/2022   0  CHO  /teams/CHO/2022.html
# 4      5  2021-10-27  BOS  /teams/BOS/2022   1  WAS  /teams/WAS/2022.html
# ..   ...         ...  ...              ...  ..  ...                   ...
# 77    78  2022-04-01  BOS  /teams/BOS/2022   1  IND  /teams/IND/2022.html
# 78    79  2022-04-03  BOS  /teams/BOS/2022   1  WAS  /teams/WAS/2022.html
# 79    80  2022-04-06  BOS  /teams/BOS/2022   0  CHI  /teams/CHI/2022.html
# 80    81  2022-04-07  BOS  /teams/BOS/2022   0  MIL  /teams/MIL/2022.html
# 81    82  2022-04-10  BOS  /teams/BOS/2022   0  MEM  /teams/MEM/2022.html
#
#    Result            ... Opponent
# ...
