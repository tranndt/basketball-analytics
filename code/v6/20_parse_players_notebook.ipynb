# %%
import pandas as pd
import numpy as np
import sys
import os
import bs4
from IPython.display import display_html,clear_output, HTML
import re
from datetime import datetime
import ast
import itertools
from tqdm import tqdm,trange
from file_tools import *
from request_tools import *
from parse_tools import *


pd.set_option('display.max_columns', None)
pd.set_option('display.min_rows', 20)
pd.set_option('compute.use_numexpr', False)

# %% [markdown]
# ![](./__images__/20_001.jpg)

# %%
# q: How to insert image into markdown cell in jupyter notebook?
# a: ![title](path/to/image.png)

# %%
gamelog_year_html = './01-data-html/players/b/bookede01/gamelog/2023.html'
html_text,html_soup = load_html(gamelog_year_html)
html_text = clean_html_text(html_text)
html_soup = bs4.BeautifulSoup(html_text, 'html.parser')
html_regular = html_soup.find('table', {'id': 'pgl_basic'})
html_playoffs = html_soup.find('table', {'id': 'pgl_basic_playoffs'})

gamelog_year_html = './01-data-html/players/b/bookede01/gamelog-advanced/2023.html'
html_text,html_soup = load_html(gamelog_year_html)
html_text = clean_html_text(html_text)
html_soup = bs4.BeautifulSoup(html_text, 'html.parser')
html_advanced_regular = html_soup.find('table', {'id': 'pgl_advanced'})
html_advanced_playoffs = html_soup.find('table', {'id': 'pgl_advanced_playoffs'})
# html_basic_playoffs

# %%
# Tasks
def __parse_player_gamelog_basic_advanced_table__(html_text):
#    1. Extract links from table - # 2. Insert links into table
    DF_PLYR_GL = parse_html_table(html_text)
    df_gamelog_basic_links = parse_html_table(html_text,extract_links='body').applymap(lambda x: x[-1])

    DF_PLYR_GL.insert(3,'Boxscore_id',df_gamelog_basic_links['Date'])
    DF_PLYR_GL.insert(6,'Tm_id',df_gamelog_basic_links['Tm'])
    DF_PLYR_GL.insert(9,'Opp_id',df_gamelog_basic_links['Opp'])

    DF_PLYR_GL = DF_PLYR_GL[~DF_PLYR_GL['Boxscore_id'].isin(['/boxscores/201606190CLE.html'])] # Fix for 201606190CLE - This game does not exist, 201606190GSW is the correct game

    # 3. Remove unnnecessary header rows
    GAME_FILTER = DF_PLYR_GL.loc[:,'Rk'].astype(str).str.isnumeric().fillna(False)
    DF_PLYR_GL = DF_PLYR_GL.loc[GAME_FILTER]
    DF_PLYR_GL.insert(2,'GP',DF_PLYR_GL.loc[:,'G'].astype(str).str.isnumeric().fillna(False).astype(int))
    # 4. Rename H/A, convert to boolean
    GAME_HM_AW = DF_PLYR_GL.pop('Unnamed: 5').isna().astype(int)
    DF_PLYR_GL.insert(8,'H/A',GAME_HM_AW)
    DF_PLYR_GL
    # 5. Rename W/L, split into 2 columns, convert to boolean and int
    GAME_RESULT = DF_PLYR_GL.pop('Unnamed: 7').str.extract(r'([WL]) \(([+-]\d+)\)',expand=True)
    DF_PLYR_GL.insert(11,'W/L',GAME_RESULT[0].replace({'W':1,'L':0}))
    DF_PLYR_GL.insert(12,'Pts_diff',GAME_RESULT[1].astype(int))
    DF_PLYR_GL
    # 6. Convert MP to float, and Inactive game stats to nan
    GP_FILTER = DF_PLYR_GL.loc[:,'GP'].astype(bool)
    # Deal with cases where MP is nan 
    if DF_PLYR_GL['MP'].notna().sum() > 0: # Added later to fix the all NAN case
        DF_PLYR_GL.loc[GP_FILTER & DF_PLYR_GL['MP'].notna(),'MP'] = DF_PLYR_GL.loc[GP_FILTER & DF_PLYR_GL['MP'].notna(),'MP'].str.split(':').apply(lambda x:float(x[0]) + float(x[1])/60)
    DF_PLYR_GL.loc[~GP_FILTER,'GS':] = np.nan
    # 7. Convert +/- to float (in basic table)
    if '+/-' in DF_PLYR_GL.columns:
        DF_PLYR_GL['+/-'] = DF_PLYR_GL['+/-'].astype(float)
    return DF_PLYR_GL

PLYR_GL_BAS_REG = __parse_player_gamelog_basic_advanced_table__(html_regular.prettify())
PLYR_GL_BAS_POFF = __parse_player_gamelog_basic_advanced_table__(html_playoffs.prettify())
PLYR_GL_ADV_REG = __parse_player_gamelog_basic_advanced_table__(html_advanced_regular.prettify())
PLYR_GL_ADV_POFF = __parse_player_gamelog_basic_advanced_table__(html_advanced_playoffs.prettify())

# %%
PLYR_GL_BAS_REG
# Out:
#     Rk    G  GP        Date                   Boxscore_id     Age   Tm
# 0    1    1   1  2022-10-19  /boxscores/202210190PHO.html  25-354  PHO  \
# 1    2    2   1  2022-10-21  /boxscores/202210210POR.html  25-356  PHO
# 2    3    3   1  2022-10-23  /boxscores/202210230LAC.html  25-358  PHO
# 3    4    4   1  2022-10-25  /boxscores/202210250PHO.html  25-360  PHO
# 4    5    5   1  2022-10-28  /boxscores/202210280PHO.html  25-363  PHO
# 5    6    6   1  2022-10-30  /boxscores/202210300PHO.html  26-000  PHO
# 6    7    7   1  2022-11-01  /boxscores/202211010PHO.html  26-002  PHO
# 7    8    8   1  2022-11-04  /boxscores/202211040PHO.html  26-005  PHO
# 8    9    9   1  2022-11-05  /boxscores/202211050PHO.html  26-006  PHO
# 9   10   10   1  2022-11-07  /boxscores/202211070PHI.html  26-008  PHO
# ..  ..  ...  ..         ...                           ...     ...  ...
# 75  73   46   1  2023-03-24  /boxscores/202303240SAC.html  26-145  PHO
# 76  74   47   1  2023-03-25  /boxscores/202303250PHO.html  26-146  PHO
# 77  75   48   1  2023-03-27  /boxscores/202303270UTA.html  26-148  PHO
# 78  76   49   1  2023-03-29  /boxscores/202303290PHO.html  26-150  PHO
# 79  77   50   1  2023-03-31  /boxscores/202303310PHO.html  26-152  PHO
# 80  78   51   1  2023-04-02  /boxscores/202304020OKC.html  26-154  PHO
# 81  79   52   1  2023-04-04  /boxscores/202304040PHO.html  26-156  PHO
# 82  80   53   1  2023-04-06  /boxscores/202304060PHO.html  26-158  PHO
# 84  81  NaN   0  2023-04-07  /boxscores/202304070LAL.html  26-159  PHO
# 85  82  NaN   0  2023-04-09  /boxscores/202304090PHO.html  26-161  PHO
#
#                    Tm_id  H/A  Opp                Opp_id  W/L  Pts_diff   GS
# 0   /teams/PHO/2023.html    1  DAL  /teams/DAL/2023.html    1         2    1  \
# 1   /teams/PHO/2023.html    0  POR  /teams/POR/2023.html    0        -2    1
# 2   /teams/PHO/2023.html    0  LAC  /teams/LAC/2023.html    1        17    1
# 3   /teams/PHO/2023.html    1  GSW  /teams/GSW/2023.html    1        29    1
# 4   /teams/PHO/2023.html    1  NOP  /teams/NOP/2023.html    1        13    1
# 5   /teams/PHO/2023.html    1  HOU  /teams/HOU/2023.html    1        15    1
# 6   /teams/PHO/2023.html    1  MIN  /teams/MIN/2023.html    1         9    1
# 7   /teams/PHO/2023.html    1  POR  /teams/POR/2023.html    0        -2    1
# 8   /teams/PHO/2023.html    1  POR  /teams/POR/2023.html    1        20    1
# 9   /teams/PHO/2023.html    0  PHI  /teams/PHI/2023.html    0       -12    1
# ..                   ...  ...  ...                   ...  ...       ...  ...
# 75  /teams/PHO/2023.html    0  SAC  /teams/SAC/2023.html    0        -8    1
# 76  /teams/PHO/2023.html    1  PHI  /teams/PHI/2023.html    1        20    1
# 77  /teams/PHO/2023.html    0  UTA  /teams/UTA/2023.html    1        14    1
# 78  /teams/PHO/2023.html    1  MIN  /teams/MIN/2023.html    1         7    1
# 79  /teams/PHO/2023.html    1  DEN  /teams/DEN/2023.html    1         7    1
# 80  /teams/PHO/2023.html    0  OKC  /teams/OKC/2023.html    1        10    1
# 81  /teams/PHO/2023.html    1  SAS  /teams/SAS/2023.html    1        21    1
# 82  /teams/PHO/2023.html    1  DEN  /teams/DEN/2023.html    1         4    1
# 84  /teams/PHO/2023.html    0  LAL  /teams/LAL/2023.html    0       -14  NaN
# 85  /teams/PHO/2023.html    1  LAC  /teams/LAC/2023.html    0        -5  NaN
#
#            MP   FG  FGA   FG%   3P  3PA    3P%   FT  FTA    FT%  ORB  DRB
# 0   40.616667   10   20  .500    1    1  1.000    7    7  1.000    1    3  \
# 1   43.916667   11   23  .478    3    7   .429    8    9   .889    0    5
# 2   34.816667   13   21  .619    5    9   .556    4    4  1.000    1    0
# 3   35.316667   10   19  .526    3    8   .375   11   14   .786    1    1
# 4        32.6    6   14  .429    0    4   .000    4    4  1.000    0    5
# 5   35.383333   14   24  .583    1    7   .143    1    3   .333    1    2
# 6   30.433333    6   18  .333    2    7   .286    4    5   .800    1    6
# 7   38.366667    8   21  .381    3    7   .429    6    6  1.000    0    5
# 8   29.166667    9   20  .450    2    7   .286    4    4  1.000    1    2
# 9        43.4    8   16  .500    1    1  1.000   11   14   .786    2    5
# ..        ...  ...  ...   ...  ...  ...    ...  ...  ...    ...  ...  ...
# 75  33.166667   10   16  .625    0    1   .000   12   14   .857    1    7
# 76      31.65    9   18  .500    2    4   .500    9    9  1.000    0    3
# 77  33.516667    7   19  .368    2    6   .333    8    8  1.000    4    3
# 78      36.35    8   18  .444    1    4   .250   12   15   .800    1    2
# 79  35.066667    9   20  .450    2    9   .222    7    8   .875    0    2
# 80      36.95    8   14  .571    1    5   .200    5    5  1.000    1    4
# 81  32.883333    9   21  .429    2   10   .200    7    8   .875    0    7
# 82  37.466667    3   12  .250    1    5   .200    8    8  1.000    0    1
# 84        NaN  NaN  NaN   NaN  NaN  NaN    NaN  NaN  NaN    NaN  NaN  NaN
# 85        NaN  NaN  NaN   NaN  NaN  NaN    NaN  NaN  NaN    NaN  NaN  NaN
#
#     TRB  AST  STL  BLK  TOV   PF  PTS  GmSc   +/-
# 0     4    9    0    1    2    3   28  23.4  20.0
# 1     5    3    1    0    2    1   33  23.1  -2.0
# 2     1    4    1    0    3    1   35  26.6  13.0
# 3     2    7    3    0    3    3   34  28.2  32.0
# 4     5    4    0    0    5    1   16   7.5   4.0
# 5     3    6    1    0    1    2   30  22.7  11.0
# 6     7    5    0    1    2    5   18  10.1  11.0
# 7     5    5    1    1    5    3   25  14.0   3.0
# 8     3    3    1    2    1    2   24  17.6  19.0
# 9     7    5    1    0    6    2   28  19.4  -9.0
# ..  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 75    8    5    0    0    2    4   32  26.7 -13.0
# 76    3    5    0    1    4    2   29  20.3   8.0
# 77    7    5    2    1    4    3   24  18.2  10.0
# 78    3    5    4    0    3    4   29  22.6  12.0
# 79    2    6    1    0    4    2   27  17.2   NaN
# 80    5   10    1    0    5    4   22  18.7   5.0
# 81    7    3    3    0    2    2   27  19.9   5.0
# 82    1    8    0    0    2    3   15  10.5  10.0
# 84  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN
# 85  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN
#
# [82 rows x 35 columns]

# %%
SRC_DIR = './01-data-html/players/'
TGT_DIR = './02-data-parsed/players/'
# player_id = '/players/b/.html' # aminual01
def parse_all_player_gamelogs_from_dir(SRC_DIR,TGT_DIR):
    player_list = load_file('./00-data-facts/players_hrefs.txt').split('\n')
    TRANGE = trange(len(player_list),ncols=150)
    for alphabet_dir in sorted(get_all_folders(SRC_DIR)): # alphabet from a-z
        for player_dir in sorted(get_all_folders('/'.join([SRC_DIR,alphabet_dir]))): # player_id such as bookede01
            for gamelog_type in sorted(get_all_folders('/'.join([SRC_DIR,alphabet_dir,player_dir]))): # gamelog or gamelog-advanced
                for gamelog_year_html in sorted(get_all_files('/'.join([SRC_DIR,alphabet_dir,player_dir,gamelog_type]),file_type='html')):
                    TRANGE.set_description('/'.join([SRC_DIR,alphabet_dir,player_dir,gamelog_type,gamelog_year_html]),refresh=True)
                    html_text,html_soup = load_html('/'.join([SRC_DIR,alphabet_dir,player_dir,gamelog_type,gamelog_year_html]))
                    html_text = clean_html_text(html_text)
                    html_soup = bs4.BeautifulSoup(html_text, 'html.parser')
                    if gamelog_type == 'gamelog':
                        html_regular = html_soup.find('table', {'id': 'pgl_basic'})
                        html_playoffs = html_soup.find('table', {'id': 'pgl_basic_playoffs'})
                    elif gamelog_type == 'gamelog-advanced':
                        html_regular = html_soup.find('table', {'id': 'pgl_advanced'})
                        html_playoffs = html_soup.find('table', {'id': 'pgl_advanced_playoffs'})
                    if html_regular:
                        tgl_name = 'pgl_basic_regular' if gamelog_type == 'gamelog' else 'pgl_advanced_regular'
                        make_directory('/'.join([TGT_DIR,alphabet_dir,player_dir,tgl_name]))
                        PGL_REG = __parse_player_gamelog_basic_advanced_table__(html_regular.prettify())
                        PGL_REG.to_csv('/'.join([TGT_DIR,alphabet_dir,player_dir,tgl_name,gamelog_year_html.replace('.html','.csv')]),index=False)
                    if html_playoffs:
                        tgl_name = 'pgl_basic_playoffs' if gamelog_type == 'gamelog' else 'pgl_advanced_playoffs'
                        make_directory('/'.join([TGT_DIR,alphabet_dir,player_dir,tgl_name]))
                        PGL_POFF = __parse_player_gamelog_basic_advanced_table__(html_playoffs.prettify())
                        PGL_POFF.to_csv('/'.join([TGT_DIR,alphabet_dir,player_dir,tgl_name,gamelog_year_html.replace('.html','.csv')]),index=False)
            TRANGE.update(1)

parse_all_player_gamelogs_from_dir(SRC_DIR,TGT_DIR)

# %%
player_id = '/players/a/aminual01.html' # aminual01
html_text,html_soup = load_html(gamelog_year_html)
html_text = clean_html_text(html_text)
html_soup = bs4.BeautifulSoup(html_text, 'html.parser')
html_regular = html_soup.find('table', {'id': 'pgl_basic'})
html_playoffs = html_soup.find('table', {'id': 'pgl_basic_playoffs'})

# %% [markdown]
# Debug failed cases - Mostly in the early eras

# %%
# Find failed cases
SRC_DIR = './01-data-html/players/'
TGT_DIR = './02-data-parsed/players/'
get_all_files_recursive(SRC_DIR,file_type='html')[:100]

to_reparse = []
TQDM_SRC_FILES = tqdm(get_all_files_recursive(SRC_DIR,file_type='html'),ncols=150)
for src_file in TQDM_SRC_FILES:
    TQDM_SRC_FILES.set_description(src_file,refresh=True)
    # Get the corresponding parsed file:
    if 'gamelog' in src_file:
        tgt_file_regular = src_file.replace(SRC_DIR,TGT_DIR).replace('gamelog','pgl_basic_regular').replace('.html','.csv')
        tgt_file_playoffs = src_file.replace(SRC_DIR,TGT_DIR).replace('gamelog','pgl_basic_playoffs').replace('.html','.csv')
    elif 'gamelog-advanced' in src_file:
        tgt_file_regular = src_file.replace(SRC_DIR,TGT_DIR).replace('gamelog-advanced','pgl_advanced_regular').replace('.html','.csv')
        tgt_file_playoffs = src_file.replace(SRC_DIR,TGT_DIR).replace('gamelog-advanced','pgl_advanced_playoffs').replace('.html','.csv')
    else:
        continue
    if not os.path.isfile(tgt_file_playoffs):
        to_reparse.append(src_file)

print(len(to_reparse))
# Out:
# ./01-data-html/players/z/zunicma01/gamelog/1949.html: 100%|███████████████████████████████████████████████████| 56850/56850 [00:23<00:00, 2470.01it/s]
# 40720

# %%
fixed_cases = load_file('./00-data-facts/fixed_player_gamelogs.txt').split('\n')
for fixed_case in fixed_cases:
    df = pd.read_csv(fixed_case.replace('..','.'))
    print(fixed_case)
    display(df)
    time.sleep(2)
    clear_output(wait=True)
# Out:
# ../02-data-parsed/players//b/brownda01/pgl_advanced_regular/1949.csv
#    Rk  G  GP        Date                   Boxscore_id     Age   Tm
# 0   1  1   1  1948-11-04  /boxscores/194811040BLB.html  25-235  BLB  \
# 1   2  2   1  1948-11-06  /boxscores/194811060CHS.html  25-237  BLB
# 2   3  3   1  1948-11-13  /boxscores/194811130NYK.html  25-244  BLB
#
#                   Tm_id  H/A  Opp                Opp_id  W/L  Pts_diff  GS
# 0  /teams/BLB/1949.html    1  MNL  /teams/MNL/1949.html    0       -12 NaN  \
# 1  /teams/BLB/1949.html    0  CHS  /teams/CHS/1949.html    0       -13 NaN
# 2  /teams/BLB/1949.html    0  NYK  /teams/NYK/1949.html    0        -4 NaN
#
#    MP  TS%  ORB%  DRB%  TRB%  AST%  ORtg  DRtg
# 0 NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1 NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2 NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jasetran/Jase/UM/Git/basketball-analytics/code/v6/20_parse_players_notebook.ipynb Cell 11 line 6
#       <a href='vscode-notebook-cell:/Users/jasetran/Jase/UM/Git/basketball-analytics/code/v6/20_parse_players_notebook.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> print(fixed_case)
#       <a href='vscode-notebook-cell:/Users/jasetran/Jase/UM/Git/basketball-analytics/code/v6/20_parse_players_notebook.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> display(df)
# ----> <a href='vscode-notebook-cell:/Users/jasetran/Jase/UM/Git/basketball-analytics/code/v6/20_parse_players_notebook.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a> time.sleep(2)
#       <a href='vscode-notebook-cell:/Users/jasetran/Jase/UM/Git/basketball-analytics/code/v6/20_parse_players_notebook.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a> clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
failed_cases = load_file('./00-data-facts/failed_player_gamelogs.txt').split('\n')
for failed_case in failed_cases:
    print(failed_case)
    url = failed_case.replace('..','.')
    html_text,html_soup = load_html(url)
    html_text = clean_html_text(html_text)
    html_soup = bs4.BeautifulSoup(html_text, 'html.parser')

# %%
pd.read_csv('./02-data-parsed/players/g/greendr01/pgl_basic_playoffs/2016.csv')
# Out:
#     Rk     G  GP        Date                   Boxscore_id     Age   Tm
# 0    1   1.0   1  2016-04-16  /boxscores/201604160GSW.html  26-043  GSW  \
# 1    2   2.0   1  2016-04-18  /boxscores/201604180GSW.html  26-045  GSW
# 2    3   3.0   1  2016-04-21  /boxscores/201604210HOU.html  26-048  GSW
# 3    4   4.0   1  2016-04-24  /boxscores/201604240HOU.html  26-051  GSW
# 4    5   5.0   1  2016-04-27  /boxscores/201604270GSW.html  26-054  GSW
# 5    6   6.0   1  2016-05-01  /boxscores/201605010GSW.html  26-058  GSW
# 6    7   7.0   1  2016-05-03  /boxscores/201605030GSW.html  26-060  GSW
# 7    8   8.0   1  2016-05-07  /boxscores/201605070POR.html  26-064  GSW
# 8    9   9.0   1  2016-05-09  /boxscores/201605090POR.html  26-066  GSW
# 9   10  10.0   1  2016-05-11  /boxscores/201605110GSW.html  26-068  GSW
# 10  11  11.0   1  2016-05-16  /boxscores/201605160GSW.html  26-073  GSW
# 11  12  12.0   1  2016-05-18  /boxscores/201605180GSW.html  26-075  GSW
# 12  13  13.0   1  2016-05-22  /boxscores/201605220OKC.html  26-079  GSW
# 13  14  14.0   1  2016-05-24  /boxscores/201605240OKC.html  26-081  GSW
# 14  15  15.0   1  2016-05-26  /boxscores/201605260GSW.html  26-083  GSW
# 15  16  16.0   1  2016-05-28  /boxscores/201605280OKC.html  26-085  GSW
# 16  17  17.0   1  2016-05-30  /boxscores/201605300GSW.html  26-087  GSW
# 17  18  18.0   1  2016-06-02  /boxscores/201606020GSW.html  26-090  GSW
# 18  19  19.0   1  2016-06-05  /boxscores/201606050GSW.html  26-093  GSW
# 19  20  20.0   1  2016-06-08  /boxscores/201606080CLE.html  26-096  GSW
# 20  21  21.0   1  2016-06-10  /boxscores/201606100CLE.html  26-098  GSW
# 21  22   NaN   0  2016-06-13  /boxscores/201606130GSW.html  26-101  GSW
# 22  23  22.0   1  2016-06-16  /boxscores/201606160CLE.html  26-104  GSW
# 23  24  23.0   1  2016-06-19  /boxscores/201606190GSW.html  26-107  GSW
#
#                    Tm_id  H/A  Opp                Opp_id  W/L  Pts_diff   GS
# 0   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html    1        26  1.0  \
# 1   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html    1         9  1.0
# 2   /teams/GSW/2016.html    0  HOU  /teams/HOU/2016.html    0        -1  1.0
# 3   /teams/GSW/2016.html    0  HOU  /teams/HOU/2016.html    1        27  1.0
# 4   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html    1        33  1.0
# 5   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html    1        12  1.0
# 6   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html    1        11  1.0
# 7   /teams/GSW/2016.html    0  POR  /teams/POR/2016.html    0       -12  1.0
# 8   /teams/GSW/2016.html    0  POR  /teams/POR/2016.html    1         7  1.0
# 9   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html    1         4  1.0
# 10  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html    0        -6  1.0
# 11  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html    1        27  1.0
# 12  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html    0       -28  1.0
# 13  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html    0       -24  1.0
# 14  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html    1         9  1.0
# 15  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html    1         7  1.0
# 16  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html    1         8  1.0
# 17  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html    1        15  1.0
# 18  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html    1        33  1.0
# 19  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html    0       -30  1.0
# 20  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html    1        11  1.0
# 21  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html    0       -15  NaN
# 22  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html    0       -14  1.0
# 23  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html    0        -4  1.0
#
#            MP    FG   FGA    FG%   3P   3PA    3P%   FT   FTA    FT%  ORB
# 0   33.283333   5.0  12.0  0.417  1.0   3.0  0.333  1.0   3.0  0.333  2.0  \
# 1   39.066667   4.0  12.0  0.333  0.0   2.0  0.000  4.0   6.0  0.667  4.0
# 2   37.266667   3.0   9.0  0.333  0.0   2.0  0.000  3.0   6.0  0.500  0.0
# 3   35.850000   7.0  12.0  0.583  4.0   6.0  0.667  0.0   2.0  0.000  1.0
# 4   31.216667   5.0   9.0  0.556  2.0   5.0  0.400  3.0   4.0  0.750  0.0
# 5   37.316667   6.0  14.0  0.429  2.0   5.0  0.400  9.0   9.0  1.000  4.0
# 6   40.816667   7.0  20.0  0.350  0.0   5.0  0.000  3.0   4.0  0.750  2.0
# 7   40.716667  13.0  23.0  0.565  8.0  12.0  0.667  3.0   6.0  0.500  2.0
# 8   44.283333   5.0   9.0  0.556  2.0   3.0  0.667  9.0  10.0  0.900  1.0
# 9   35.850000   2.0   7.0  0.286  1.0   5.0  0.200  8.0  10.0  0.800  1.0
# 10  40.083333   9.0  20.0  0.450  0.0   4.0  0.000  5.0   9.0  0.556  1.0
# 11  32.133333   4.0   9.0  0.444  2.0   4.0  0.500  0.0   0.0    NaN  2.0
# 12  31.816667   1.0   9.0  0.111  0.0   2.0  0.000  4.0   4.0  1.000  1.0
# 13  37.666667   1.0   7.0  0.143  0.0   2.0  0.000  4.0   4.0  1.000  2.0
# 14  39.266667   4.0  10.0  0.400  0.0   2.0  0.000  3.0   3.0  1.000  5.0
# 15  42.666667   4.0  10.0  0.400  2.0   5.0  0.400  2.0   4.0  0.500  3.0
# 16  40.116667   5.0  14.0  0.357  1.0   5.0  0.200  0.0   0.0    NaN  2.0
# 17  40.283333   5.0  11.0  0.455  2.0   6.0  0.333  4.0   4.0  1.000  0.0
# 18  33.866667  11.0  20.0  0.550  5.0   8.0  0.625  1.0   1.0  1.000  1.0
# 19  35.933333   2.0   8.0  0.250  0.0   4.0  0.000  2.0   4.0  0.500  1.0
# 20  42.233333   2.0   9.0  0.222  0.0   4.0  0.000  5.0   8.0  0.625  1.0
# 21        NaN   NaN   NaN    NaN  NaN   NaN    NaN  NaN   NaN    NaN  NaN
# 22  40.733333   3.0   7.0  0.429  0.0   2.0  0.000  2.0   2.0  1.000  1.0
# 23  46.900000  11.0  15.0  0.733  6.0   8.0  0.750  4.0   4.0  1.000  1.0
#
#      DRB   TRB   AST  STL  BLK  TOV   PF   PTS  GmSc   +/-
# 0    8.0  10.0   4.0  2.0  4.0  1.0  5.0  12.0  13.2  28.0
# 1   10.0  14.0   8.0  2.0  1.0  0.0  2.0  12.0  17.7   9.0
# 2    7.0   7.0   7.0  1.0  0.0  7.0  5.0   9.0   1.7  -7.0
# 3    7.0   8.0   6.0  1.0  0.0  4.0  4.0  18.0  14.0  34.0
# 4    9.0   9.0   8.0  1.0  2.0  0.0  2.0  15.0  20.2  32.0
# 5    9.0  13.0  11.0  1.0  3.0  2.0  2.0  23.0  29.1  24.0
# 6   12.0  14.0   7.0  1.0  4.0  2.0  4.0  17.0  15.5  19.0
# 7    7.0   9.0   8.0  1.0  1.0  2.0  2.0  37.0  32.9  -2.0
# 8    8.0   9.0   5.0  4.0  7.0  2.0  5.0  21.0  27.8   8.0
# 9   10.0  11.0   6.0  2.0  1.0  4.0  5.0  13.0  12.7   0.0
# 10   4.0   5.0   4.0  1.0  2.0  2.0  3.0  23.0  14.9   0.0
# 11   6.0   8.0   7.0  1.0  2.0  1.0  3.0  10.0  13.6  24.0
# 12   3.0   4.0   3.0  1.0  0.0  4.0  3.0   6.0  -0.4 -43.0
# 13   9.0  11.0   2.0  3.0  1.0  6.0  3.0   6.0   3.5 -30.0
# 14   8.0  13.0   4.0  1.0  4.0  2.0  4.0  11.0  14.5   2.0
# 15   9.0  12.0   6.0  3.0  1.0  3.0  5.0  12.0  13.5  16.0
# 16   7.0   9.0   4.0  1.0  2.0  2.0  5.0  11.0   7.9   3.0
# 17  11.0  11.0   7.0  4.0  1.0  3.0  1.0  16.0  19.8  17.0
# 18   6.0   7.0   5.0  1.0  0.0  1.0  2.0  28.0  23.6  20.0
# 19   6.0   7.0   7.0  0.0  1.0  2.0  4.0   6.0   4.9 -15.0
# 20  11.0  12.0   4.0  2.0  3.0  3.0  4.0   9.0   8.6  14.0
# 21   NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 22   9.0  10.0   6.0  1.0  1.0  1.0  5.0   8.0  10.6 -12.0
# 23  14.0  15.0   9.0  2.0  0.0  2.0  3.0  32.0  35.9  -1.0

# %%
players/d/dellama01/gamelog-advanced/2016

# %%
url = './01-data-html/players/m/mcadoja01/gamelog-advanced/2016.html'
html_text,html_soup = load_html(url)
html_text = clean_html_text(html_text)
html_soup = bs4.BeautifulSoup(html_text, 'html.parser')
# HTML(html_text)
html_advanced_playoffs = html_soup.find('table', {'id': 'pgl_advanced_playoffs'})
html_text = html_advanced_playoffs.prettify()

DF_PLYR_GL = parse_html_table(html_text)
df_gamelog_basic_links = parse_html_table(html_text,extract_links='body').applymap(lambda x: x[-1])
DF_PLYR_GL.insert(3,'Boxscore_id',df_gamelog_basic_links['Date'])
DF_PLYR_GL.insert(6,'Tm_id',df_gamelog_basic_links['Tm'])
DF_PLYR_GL.insert(9,'Opp_id',df_gamelog_basic_links['Opp'])
# 3. Remove unnnecessary header rows
GAME_FILTER = DF_PLYR_GL.loc[:,'Rk'].astype(str).str.isnumeric().fillna(False)
DF_PLYR_GL = DF_PLYR_GL.loc[GAME_FILTER]
DF_PLYR_GL.insert(2,'GP',DF_PLYR_GL.loc[:,'G'].astype(str).str.isnumeric().fillna(False).astype(int))
# 4. Rename H/A, convert to boolean
GAME_HM_AW = DF_PLYR_GL.pop('Unnamed: 5').isna().astype(int)
DF_PLYR_GL.insert(8,'H/A',GAME_HM_AW)
DF_PLYR_GL
# 5. Rename W/L, split into 2 columns, convert to boolean and int
GAME_RESULT = DF_PLYR_GL.pop('Unnamed: 7').str.extract(r'([WL]) \(([+-]\d+)\)',expand=True)
DF_PLYR_GL.insert(11,'W/L',GAME_RESULT[0].replace({'W':1,'L':0}))
DF_PLYR_GL.insert(12,'Pts_diff',GAME_RESULT[1].astype(int))
DF_PLYR_GL
# 6. Convert MP to float, and Inactive game stats to nan
GP_FILTER = DF_PLYR_GL.loc[:,'GP'].astype(bool)
# Deal with cases where MP is nan 
if DF_PLYR_GL['MP'].notna().sum() > 0:
    DF_PLYR_GL.loc[GP_FILTER & DF_PLYR_GL['MP'].notna(),'MP'] = DF_PLYR_GL.loc[GP_FILTER & DF_PLYR_GL['MP'].notna(),'MP'].str.split(':').apply(lambda x:float(x[0]) + float(x[1])/60)
DF_PLYR_GL.loc[~GP_FILTER,'GS':] = np.nan
# # 7. Convert +/- to float (in basic table)
if '+/-' in DF_PLYR_GL.columns:
    DF_PLYR_GL['+/-'] = DF_PLYR_GL['+/-'].astype(float)
DF_PLYR_GL
# Out:
#     Rk    G  GP        Date                   Boxscore_id     Age   Tm
# 0    1  NaN   0  2016-04-16  /boxscores/201604160GSW.html  23-103  GSW  \
# 1    2  NaN   0  2016-04-18  /boxscores/201604180GSW.html  23-105  GSW
# 2    3    1   1  2016-04-21  /boxscores/201604210HOU.html  23-108  GSW
# 3    4    2   1  2016-04-24  /boxscores/201604240HOU.html  23-111  GSW
# 4    5    3   1  2016-04-27  /boxscores/201604270GSW.html  23-114  GSW
# 5    6    4   1  2016-05-01  /boxscores/201605010GSW.html  23-118  GSW
# 6    7  NaN   0  2016-05-03  /boxscores/201605030GSW.html  23-120  GSW
# 7    8    5   1  2016-05-07  /boxscores/201605070POR.html  23-124  GSW
# 8    9  NaN   0  2016-05-09  /boxscores/201605090POR.html  23-126  GSW
# 9   10  NaN   0  2016-05-11  /boxscores/201605110GSW.html  23-128  GSW
# 10  11  NaN   0  2016-05-16  /boxscores/201605160GSW.html  23-133  GSW
# 11  12  NaN   0  2016-05-18  /boxscores/201605180GSW.html  23-135  GSW
# 12  13  NaN   0  2016-05-22  /boxscores/201605220OKC.html  23-139  GSW
# 13  14  NaN   0  2016-05-24  /boxscores/201605240OKC.html  23-141  GSW
# 14  15  NaN   0  2016-05-26  /boxscores/201605260GSW.html  23-143  GSW
# 15  16  NaN   0  2016-05-28  /boxscores/201605280OKC.html  23-145  GSW
# 16  17  NaN   0  2016-05-30  /boxscores/201605300GSW.html  23-147  GSW
# 17  18  NaN   0  2016-06-02  /boxscores/201606020GSW.html  23-150  GSW
# 18  19  NaN   0  2016-06-05  /boxscores/201606050GSW.html  23-153  GSW
# 19  20  NaN   0  2016-06-08  /boxscores/201606080CLE.html  23-156  GSW
# 21  21    6   1  2016-06-10  /boxscores/201606100CLE.html  23-158  GSW
# 22  22    7   1  2016-06-13  /boxscores/201606130GSW.html  23-161  GSW
# 23  23    8   1  2016-06-16  /boxscores/201606160CLE.html  23-164  GSW
# 24  24  NaN   0  2016-06-19  /boxscores/201606190CLE.html  23-167  GSW
# 25  25  NaN   0  2016-06-19  /boxscores/201606190GSW.html  23-167  GSW
#
#                    Tm_id  H/A  Opp                Opp_id  W/L            GS
# 0   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html  1.0      Inactive  \
# 1   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html  1.0  Did Not Play
# 2   /teams/GSW/2016.html    0  HOU  /teams/HOU/2016.html  0.0             0
# 3   /teams/GSW/2016.html    0  HOU  /teams/HOU/2016.html  1.0             0
# 4   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html  1.0             0
# 5   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html  1.0             0
# 6   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html  1.0  Did Not Play
# 7   /teams/GSW/2016.html    0  POR  /teams/POR/2016.html  0.0             0
# 8   /teams/GSW/2016.html    0  POR  /teams/POR/2016.html  1.0      Inactive
# 9   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html  1.0      Inactive
# 10  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  0.0      Inactive
# 11  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  1.0      Inactive
# 12  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html  0.0      Inactive
# 13  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html  0.0      Inactive
# 14  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  1.0  Did Not Play
# 15  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html  1.0  Did Not Play
# 16  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  1.0      Inactive
# 17  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  1.0      Inactive
# 18  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  1.0      Inactive
# 19  /teams/GSW/2016.html    0  GSW  /teams/GSW/2016.html  0.0      Inactive
# 21  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html  1.0             0
# 22  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  0.0             0
# 23  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html  0.0             0
# 24  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  NaN  Did Not Play
# 25  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  0.0  Did Not Play
#
#               MP           TS%          eFG%          ORB%          DRB%
# 0       Inactive      Inactive      Inactive      Inactive      Inactive  \
# 1   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 2           7:34          .568           NaN           0.0          49.8
# 3           5:50          .000          .000           0.0           0.0
# 4           3:26           NaN           NaN           0.0           0.0
# 5           1:13           NaN           NaN           0.0           0.0
# 6   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 7           1:22           NaN           NaN           0.0           0.0
# 8       Inactive      Inactive      Inactive      Inactive      Inactive
# 9       Inactive      Inactive      Inactive      Inactive      Inactive
# 10      Inactive      Inactive      Inactive      Inactive      Inactive
# 11      Inactive      Inactive      Inactive      Inactive      Inactive
# 12      Inactive      Inactive      Inactive      Inactive      Inactive
# 13      Inactive      Inactive      Inactive      Inactive      Inactive
# 14  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 15  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 16      Inactive      Inactive      Inactive      Inactive      Inactive
# 17      Inactive      Inactive      Inactive      Inactive      Inactive
# 18      Inactive      Inactive      Inactive      Inactive      Inactive
# 19      Inactive      Inactive      Inactive      Inactive      Inactive
# 21          7:24         1.000         1.000           0.0          14.4
# 22          7:37           NaN           NaN           0.0          33.2
# 23          3:23         1.000         1.000           0.0          41.7
# 24  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 25  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
#
#             TRB%          AST%          STL%          BLK%          TOV%
# 0       Inactive      Inactive      Inactive      Inactive      Inactive  \
# 1   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 2           26.7           0.0           0.0          22.7           0.0
# 3            0.0          17.9           8.0           0.0          25.8
# 4            0.0           0.0          30.2           0.0           NaN
# 5            0.0           0.0           0.0           0.0           NaN
# 6   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 7            0.0           0.0           0.0           0.0           NaN
# 8       Inactive      Inactive      Inactive      Inactive      Inactive
# 9       Inactive      Inactive      Inactive      Inactive      Inactive
# 10      Inactive      Inactive      Inactive      Inactive      Inactive
# 11      Inactive      Inactive      Inactive      Inactive      Inactive
# 12      Inactive      Inactive      Inactive      Inactive      Inactive
# 13      Inactive      Inactive      Inactive      Inactive      Inactive
# 14  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 15  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 16      Inactive      Inactive      Inactive      Inactive      Inactive
# 17      Inactive      Inactive      Inactive      Inactive      Inactive
# 18      Inactive      Inactive      Inactive      Inactive      Inactive
# 19      Inactive      Inactive      Inactive      Inactive      Inactive
# 21           7.8          24.5           0.0           0.0           0.0
# 22          15.0           0.0           0.0           0.0           NaN
# 23          17.7           0.0           0.0           0.0           0.0
# 24  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 25  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
#
#             USG%          ORtg          DRtg          GmSc           BPM
# 0       Inactive      Inactive      Inactive      Inactive      Inactive
# 1   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 2            5.3           123            76           3.2          11.1
# 3           28.5            20            83          -1.9         -21.2
# 4            0.0             0            38           2.0          26.9
# 5            0.0             0           118           0.0          -7.5
# 6   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 7            0.0             0           136           0.0          -9.6
# 8       Inactive      Inactive      Inactive      Inactive      Inactive
# 9       Inactive      Inactive      Inactive      Inactive      Inactive
# 10      Inactive      Inactive      Inactive      Inactive      Inactive
# 11      Inactive      Inactive      Inactive      Inactive      Inactive
# 12      Inactive      Inactive      Inactive      Inactive      Inactive
# 13      Inactive      Inactive      Inactive      Inactive      Inactive
# 14  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 15  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 16      Inactive      Inactive      Inactive      Inactive      Inactive
# 17      Inactive      Inactive      Inactive      Inactive      Inactive
# 18      Inactive      Inactive      Inactive      Inactive      Inactive
# 19      Inactive      Inactive      Inactive      Inactive      Inactive
# 21           6.3           214           116           1.9           2.5
# 22           0.0             0           113          -0.6         -11.5
# 23          13.0           200           122           2.0          11.5
# 24  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 25  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play

# %%
df_gamelog_basic_links
# Out:
#       Rk     G                          Date   Age                    Tm
# 0   None  None  /boxscores/201604160GSW.html  None  /teams/GSW/2016.html  \
# 1   None  None  /boxscores/201604180GSW.html  None  /teams/GSW/2016.html
# 2   None  None  /boxscores/201604210HOU.html  None  /teams/GSW/2016.html
# 3   None  None  /boxscores/201604240HOU.html  None  /teams/GSW/2016.html
# 4   None  None  /boxscores/201604270GSW.html  None  /teams/GSW/2016.html
# 5   None  None  /boxscores/201605010GSW.html  None  /teams/GSW/2016.html
# 6   None  None  /boxscores/201605030GSW.html  None  /teams/GSW/2016.html
# 7   None  None  /boxscores/201605070POR.html  None  /teams/GSW/2016.html
# 8   None  None  /boxscores/201605090POR.html  None  /teams/GSW/2016.html
# 9   None  None  /boxscores/201605110GSW.html  None  /teams/GSW/2016.html
# 10  None  None  /boxscores/201605160GSW.html  None  /teams/GSW/2016.html
# 11  None  None  /boxscores/201605180GSW.html  None  /teams/GSW/2016.html
# 12  None  None  /boxscores/201605220OKC.html  None  /teams/GSW/2016.html
# 13  None  None  /boxscores/201605240OKC.html  None  /teams/GSW/2016.html
# 14  None  None  /boxscores/201605260GSW.html  None  /teams/GSW/2016.html
# 15  None  None  /boxscores/201605280OKC.html  None  /teams/GSW/2016.html
# 16  None  None  /boxscores/201605300GSW.html  None  /teams/GSW/2016.html
# 17  None  None  /boxscores/201606020GSW.html  None  /teams/GSW/2016.html
# 18  None  None  /boxscores/201606050GSW.html  None  /teams/GSW/2016.html
# 19  None  None  /boxscores/201606080CLE.html  None  /teams/GSW/2016.html
# 20  None  None                          None  None                  None
# 21  None  None  /boxscores/201606100CLE.html  None  /teams/GSW/2016.html
# 22  None  None  /boxscores/201606130GSW.html  None  /teams/GSW/2016.html
# 23  None  None  /boxscores/201606160CLE.html  None  /teams/GSW/2016.html
# 24  None  None  /boxscores/201606190CLE.html  None  /teams/GSW/2016.html
# 25  None  None  /boxscores/201606190GSW.html  None  /teams/GSW/2016.html
#
#    Unnamed: 5                   Opp Unnamed: 7    GS    MP   TS%  eFG%  ORB%
# 0        None  /teams/HOU/2016.html       None  None  None  None  None  None  \
# 1        None  /teams/HOU/2016.html       None  None  None  None  None  None
# 2        None  /teams/HOU/2016.html       None  None  None  None  None  None
# 3        None  /teams/HOU/2016.html       None  None  None  None  None  None
# 4        None  /teams/HOU/2016.html       None  None  None  None  None  None
# 5        None  /teams/POR/2016.html       None  None  None  None  None  None
# 6        None  /teams/POR/2016.html       None  None  None  None  None  None
# 7        None  /teams/POR/2016.html       None  None  None  None  None  None
# 8        None  /teams/POR/2016.html       None  None  None  None  None  None
# 9        None  /teams/POR/2016.html       None  None  None  None  None  None
# 10       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 11       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 12       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 13       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 14       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 15       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 16       None  /teams/OKC/2016.html       None  None  None  None  None  None
# 17       None  /teams/CLE/2016.html       None  None  None  None  None  None
# 18       None  /teams/CLE/2016.html       None  None  None  None  None  None
# 19       None  /teams/GSW/2016.html       None  None  None  None  None  None
# 20       None                  None       None  None  None  None  None  None
# 21       None  /teams/CLE/2016.html       None  None  None  None  None  None
# 22       None  /teams/CLE/2016.html       None  None  None  None  None  None
# 23       None  /teams/CLE/2016.html       None  None  None  None  None  None
# 24       None  /teams/CLE/2016.html       None  None  None  None  None  None
# 25       None  /teams/CLE/2016.html       None  None  None  None  None  None
#
#     DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  ORtg  DRtg  GmSc   BPM
# 0   None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None
# 20  None  None  None  None  None  None  None  None  None  None  None
# 21  None  None  None  None  None  None  None  None  None  None  None
# 22  None  None  None  None  None  None  None  None  None  None  None
# 23  None  None  None  None  None  None  None  None  None  None  None
# 24  None  None  None  None  None  None  None  None  None  None  None
# 25  None  None  None  None  None  None  None  None  None  None  None

# %%
DF_PLYR_GL[~DF_PLYR_GL['Boxscore_id'].isin(['/boxscores/201606190CLE.html'])]
# Out:
#     Rk    G  GP        Date                   Boxscore_id     Age   Tm
# 0    1  NaN   0  2016-04-16  /boxscores/201604160GSW.html  23-103  GSW  \
# 1    2  NaN   0  2016-04-18  /boxscores/201604180GSW.html  23-105  GSW
# 2    3    1   1  2016-04-21  /boxscores/201604210HOU.html  23-108  GSW
# 3    4    2   1  2016-04-24  /boxscores/201604240HOU.html  23-111  GSW
# 4    5    3   1  2016-04-27  /boxscores/201604270GSW.html  23-114  GSW
# 5    6    4   1  2016-05-01  /boxscores/201605010GSW.html  23-118  GSW
# 6    7  NaN   0  2016-05-03  /boxscores/201605030GSW.html  23-120  GSW
# 7    8    5   1  2016-05-07  /boxscores/201605070POR.html  23-124  GSW
# 8    9  NaN   0  2016-05-09  /boxscores/201605090POR.html  23-126  GSW
# 9   10  NaN   0  2016-05-11  /boxscores/201605110GSW.html  23-128  GSW
# 10  11  NaN   0  2016-05-16  /boxscores/201605160GSW.html  23-133  GSW
# 11  12  NaN   0  2016-05-18  /boxscores/201605180GSW.html  23-135  GSW
# 12  13  NaN   0  2016-05-22  /boxscores/201605220OKC.html  23-139  GSW
# 13  14  NaN   0  2016-05-24  /boxscores/201605240OKC.html  23-141  GSW
# 14  15  NaN   0  2016-05-26  /boxscores/201605260GSW.html  23-143  GSW
# 15  16  NaN   0  2016-05-28  /boxscores/201605280OKC.html  23-145  GSW
# 16  17  NaN   0  2016-05-30  /boxscores/201605300GSW.html  23-147  GSW
# 17  18  NaN   0  2016-06-02  /boxscores/201606020GSW.html  23-150  GSW
# 18  19  NaN   0  2016-06-05  /boxscores/201606050GSW.html  23-153  GSW
# 19  20  NaN   0  2016-06-08  /boxscores/201606080CLE.html  23-156  GSW
# 21  21    6   1  2016-06-10  /boxscores/201606100CLE.html  23-158  GSW
# 22  22    7   1  2016-06-13  /boxscores/201606130GSW.html  23-161  GSW
# 23  23    8   1  2016-06-16  /boxscores/201606160CLE.html  23-164  GSW
# 24  24  NaN   0  2016-06-19  /boxscores/201606190CLE.html  23-167  GSW
# 25  25  NaN   0  2016-06-19  /boxscores/201606190GSW.html  23-167  GSW
#
#                    Tm_id  H/A  Opp                Opp_id  W/L            GS
# 0   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html  1.0      Inactive  \
# 1   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html  1.0  Did Not Play
# 2   /teams/GSW/2016.html    0  HOU  /teams/HOU/2016.html  0.0             0
# 3   /teams/GSW/2016.html    0  HOU  /teams/HOU/2016.html  1.0             0
# 4   /teams/GSW/2016.html    1  HOU  /teams/HOU/2016.html  1.0             0
# 5   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html  1.0             0
# 6   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html  1.0  Did Not Play
# 7   /teams/GSW/2016.html    0  POR  /teams/POR/2016.html  0.0             0
# 8   /teams/GSW/2016.html    0  POR  /teams/POR/2016.html  1.0      Inactive
# 9   /teams/GSW/2016.html    1  POR  /teams/POR/2016.html  1.0      Inactive
# 10  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  0.0      Inactive
# 11  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  1.0      Inactive
# 12  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html  0.0      Inactive
# 13  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html  0.0      Inactive
# 14  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  1.0  Did Not Play
# 15  /teams/GSW/2016.html    0  OKC  /teams/OKC/2016.html  1.0  Did Not Play
# 16  /teams/GSW/2016.html    1  OKC  /teams/OKC/2016.html  1.0      Inactive
# 17  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  1.0      Inactive
# 18  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  1.0      Inactive
# 19  /teams/GSW/2016.html    0  GSW  /teams/GSW/2016.html  0.0      Inactive
# 21  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html  1.0             0
# 22  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  0.0             0
# 23  /teams/GSW/2016.html    0  CLE  /teams/CLE/2016.html  0.0             0
# 24  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  NaN  Did Not Play
# 25  /teams/GSW/2016.html    1  CLE  /teams/CLE/2016.html  0.0  Did Not Play
#
#               MP           TS%          eFG%          ORB%          DRB%
# 0       Inactive      Inactive      Inactive      Inactive      Inactive  \
# 1   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 2           7:34          .568           NaN           0.0          49.8
# 3           5:50          .000          .000           0.0           0.0
# 4           3:26           NaN           NaN           0.0           0.0
# 5           1:13           NaN           NaN           0.0           0.0
# 6   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 7           1:22           NaN           NaN           0.0           0.0
# 8       Inactive      Inactive      Inactive      Inactive      Inactive
# 9       Inactive      Inactive      Inactive      Inactive      Inactive
# 10      Inactive      Inactive      Inactive      Inactive      Inactive
# 11      Inactive      Inactive      Inactive      Inactive      Inactive
# 12      Inactive      Inactive      Inactive      Inactive      Inactive
# 13      Inactive      Inactive      Inactive      Inactive      Inactive
# 14  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 15  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 16      Inactive      Inactive      Inactive      Inactive      Inactive
# 17      Inactive      Inactive      Inactive      Inactive      Inactive
# 18      Inactive      Inactive      Inactive      Inactive      Inactive
# 19      Inactive      Inactive      Inactive      Inactive      Inactive
# 21          7:24         1.000         1.000           0.0          14.4
# 22          7:37           NaN           NaN           0.0          33.2
# 23          3:23         1.000         1.000           0.0          41.7
# 24  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 25  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
#
#             TRB%          AST%          STL%          BLK%          TOV%
# 0       Inactive      Inactive      Inactive      Inactive      Inactive  \
# 1   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 2           26.7           0.0           0.0          22.7           0.0
# 3            0.0          17.9           8.0           0.0          25.8
# 4            0.0           0.0          30.2           0.0           NaN
# 5            0.0           0.0           0.0           0.0           NaN
# 6   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 7            0.0           0.0           0.0           0.0           NaN
# 8       Inactive      Inactive      Inactive      Inactive      Inactive
# 9       Inactive      Inactive      Inactive      Inactive      Inactive
# 10      Inactive      Inactive      Inactive      Inactive      Inactive
# 11      Inactive      Inactive      Inactive      Inactive      Inactive
# 12      Inactive      Inactive      Inactive      Inactive      Inactive
# 13      Inactive      Inactive      Inactive      Inactive      Inactive
# 14  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 15  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 16      Inactive      Inactive      Inactive      Inactive      Inactive
# 17      Inactive      Inactive      Inactive      Inactive      Inactive
# 18      Inactive      Inactive      Inactive      Inactive      Inactive
# 19      Inactive      Inactive      Inactive      Inactive      Inactive
# 21           7.8          24.5           0.0           0.0           0.0
# 22          15.0           0.0           0.0           0.0           NaN
# 23          17.7           0.0           0.0           0.0           0.0
# 24  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 25  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
#
#             USG%          ORtg          DRtg          GmSc           BPM
# 0       Inactive      Inactive      Inactive      Inactive      Inactive
# 1   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 2            5.3           123            76           3.2          11.1
# 3           28.5            20            83          -1.9         -21.2
# 4            0.0             0            38           2.0          26.9
# 5            0.0             0           118           0.0          -7.5
# 6   Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 7            0.0             0           136           0.0          -9.6
# 8       Inactive      Inactive      Inactive      Inactive      Inactive
# 9       Inactive      Inactive      Inactive      Inactive      Inactive
# 10      Inactive      Inactive      Inactive      Inactive      Inactive
# 11      Inactive      Inactive      Inactive      Inactive      Inactive
# 12      Inactive      Inactive      Inactive      Inactive      Inactive
# 13      Inactive      Inactive      Inactive      Inactive      Inactive
# 14  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 15  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 16      Inactive      Inactive      Inactive      Inactive      Inactive
# 17      Inactive      Inactive      Inactive      Inactive      Inactive
# 18      Inactive      Inactive      Inactive      Inactive      Inactive
# 19      Inactive      Inactive      Inactive      Inactive      Inactive
# 21           6.3           214           116           1.9           2.5
# 22           0.0             0           113          -0.6         -11.5
# 23          13.0           200           122           2.0          11.5
# 24  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play
# 25  Did Not Play  Did Not Play  Did Not Play  Did Not Play  Did Not Play

# %% [markdown]
# Parsing error for G
#
# ![](./__images__/20_002.jpg)
